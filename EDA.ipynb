# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/samplesuperstore.csv")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800  01-03-2023  01-07-2023  Standard Class    DP-13000
# 1       2  US-2023-112326  01-04-2023  01-08-2023  Standard Class    PO-19195
# 2       3  US-2023-112326  01-04-2023  01-08-2023  Standard Class    PO-19195
# 3       4  US-2023-112326  01-04-2023  01-08-2023  Standard Class    PO-19195
# 4       5  US-2023-141817  01-05-2023  01-12-2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
# 3  Central  OFF-ST-10002743  Office Supplies      Storage
# 4     East  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448       2.0
# 1         GBC Standard Plastic Binding Systems Combs    3.540       2.0
# 2                                          Avery 508   11.784       3.0
# 3                      SAFCO Boltless Steel Shelving  272.736       3.0
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536       3.0
#
#    Discount   Profit
# 0       0.2   5.5512
# 1       0.8  -5.4870
# 2       0.2   4.2717
# 3       0.2 -64.7748
# 4       0.2   4.8840
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9128 entries, 0 to 9127
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9128 non-null   int64
#  1   Order ID        9127 non-null   object
#  2   Order Date      9127 non-null   object
#  3   Ship Date       9127 non-null   object
#  4   Ship Mode       9127 non-null   object
#  5   Customer ID     9127 non-null   object
#  6   Customer Name   9127 non-null   object
#  7   Segment         9127 non-null   object
#  8   Country/Region  9127 non-null   object
#  9   City            9127 non-null   object
#  10  State/Province  9127 non-null   object
#  11  Postal Code     9127 non-null   object
#  12  Region          9127 non-null   object
#  13  Product ID      9127 non-null   object
#  14  Category        9127 non-null   object
#  15  Sub-Category    9127 non-null   object
#  16  Product Name    9127 non-null   object
#  17  Sales           9127 non-null   float64
#  18  Quantity        9127 non-null   float64
#  19  Discount        9127 non-null   float64
#  20  Profit          9127 non-null   float64
# dtypes: float64(4), int64(1), object(16)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (9128, 21)

# %%
df.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  9128.000000   9127.000000  9127.000000  9127.000000  9127.000000
# mean   4563.500986    229.083092     3.786020     0.155235    29.361223
# std    2635.169256    618.234200     2.216209     0.206501   226.838421
# min       1.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2281.750000     17.230000     2.000000     0.000000     1.788850
# 50%    4563.500000     54.368000     3.000000     0.200000     8.767200
# 75%    6845.250000    209.970000     5.000000     0.200000    29.628800
# max    9127.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df['Order Date']=pd.to_datetime(df['Order Date'],format='mixed')
df['Ship Date']=pd.to_datetime(df['Ship Date'],format='mixed')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9128 entries, 0 to 9127
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9128 non-null   int64
#  1   Order ID        9127 non-null   object
#  2   Order Date      9127 non-null   datetime64[ns]
#  3   Ship Date       9127 non-null   datetime64[ns]
#  4   Ship Mode       9127 non-null   object
#  5   Customer ID     9127 non-null   object
#  6   Customer Name   9127 non-null   object
#  7   Segment         9127 non-null   object
#  8   Country/Region  9127 non-null   object
#  9   City            9127 non-null   object
#  10  State/Province  9127 non-null   object
#  11  Postal Code     9127 non-null   object
#  12  Region          9127 non-null   object
#  13  Product ID      9127 non-null   object
#  14  Category        9127 non-null   object
#  15  Sub-Category    9127 non-null   object
#  16  Product Name    9127 non-null   object
#  17  Sales           9127 non-null   float64
#  18  Quantity        9127 non-null   float64
#  19  Discount        9127 non-null   float64
#  20  Profit          9127 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(14)
# memory usage: 1.5+ MB

# %%
df['Delivery Days']=(df['Ship Date']-df['Order Date']).dt.days

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05 2023-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ...   Region  \
# 0  Darren Powers     Consumer  United States       Houston  ...  Central
# 1  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 2  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 3  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 4     Mick Brown     Consumer  United States  Philadelphia  ...     East
#
#         Product ID         Category Sub-Category  \
# 0  OFF-PA-10000174  Office Supplies        Paper
# 1  OFF-BI-10004094  Office Supplies      Binders
# 2  OFF-LA-10003223  Office Supplies       Labels
# 3  OFF-ST-10002743  Office Supplies      Storage
# 4  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448      2.0
# 1         GBC Standard Plastic Binding Systems Combs    3.540      2.0
# 2                                          Avery 508   11.784      3.0
# 3                      SAFCO Boltless Steel Shelving  272.736      3.0
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536      3.0
#
#    Discount   Profit  Delivery Days
# 0       0.2   5.5512            4.0
# 1       0.8  -5.4870            4.0
# 2       0.2   4.2717            4.0
# 3       0.2 -64.7748            4.0
# 4       0.2   4.8840            7.0
#
# [5 rows x 22 columns]

# %%
df['Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          1
# Order Date        1
# Ship Date         1
# Ship Mode         1
# Customer ID       1
# Customer Name     1
# Segment           1
# Country/Region    1
# City              1
# State/Province    1
# Postal Code       1
# Region            1
# Product ID        1
# Category          1
# Sub-Category      1
# Product Name      1
# Sales             1
# Quantity          1
# Discount          1
# Profit            1
# Delivery Days     1
# dtype: int64

# %%
category_sales = (df.groupby('Category')['Sales'].sum())
category_sales
# Out:
# Category
# Furniture          678752.4825
# Office Supplies    662959.4830
# Technology         749129.4160
# Name: Sales, dtype: float64

# %%
category_sales.plot(kind='bar',figsize=(8,5))
plt.title("Sales by Category")
plt.ylabel("Total Sales")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Sales'],bins=30)
plt.title("Sales Distribution")
plt.show()

# %%
sns.barplot(
    data=df,
    x="Category",
    y="Profit"
)

plt.title("Profit by Category")
plt.show()

# %%
sns.boxplot(
    data=df,
    y="Profit"
)

plt.title("Profit Distribution")
plt.show()

# %%
sns.boxplot(
    data=df,
    x="Category",
    y="Profit"
)

plt.title("Profit Variation Across Categories")
plt.show()

# %%
df["Discount"].unique()
# Out:
# array([0.2 , 0.8 , 0.  , 0.6 , 0.15, 0.7 , 0.5 , 0.4 , 0.1 , 0.3 , 0.32,
#        0.45,  nan])

# %%
sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit"
)

plt.title("Impact of Discount on Profit")
plt.show()

# %%
numeric_df = df.select_dtypes(
    include="number"
)

# %%
corr = numeric_df.corr()
corr
# Out:
#                  Row ID     Sales  Quantity  Discount    Profit  Delivery Days
# Row ID         1.000000 -0.007755 -0.004330 -0.002286  0.009831      -0.021582
# Sales         -0.007755  1.000000  0.203534 -0.028870  0.492433      -0.002327
# Quantity      -0.004330  0.203534  1.000000  0.005103  0.072212       0.021957
# Discount      -0.002286 -0.028870  0.005103  1.000000 -0.219258       0.001702
# Profit         0.009831  0.492433  0.072212 -0.219258  1.000000      -0.007882
# Delivery Days -0.021582 -0.002327  0.021957  0.001702 -0.007882       1.000000

# %%
sns.heatmap(
    corr,
    annot=True
)

plt.title("Correlation Heatmap")
plt.show()
